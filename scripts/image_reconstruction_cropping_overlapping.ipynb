# %%
import numpy as np
import matplotlib.pyplot as plt
import tkinter.filedialog as tkf
import glob

# %%
folder = tkf.askdirectory()
img_adr = glob.glob(folder+"/*")
print(len(img_adr))
img_adr.sort()
#print(img_adr[:30])
# Out:
# 11

# %%
img_adr = tkf.askopenfilenames()
print(len(img_adr))
# Out:
# 162

# %%
img_adr[1::2]
# Out:
# ('D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0000_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0001_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0002_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0003_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0004_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0005_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0006_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0007_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0008_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0009_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0010_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0011_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0012_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0013_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0014_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0015_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0016_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0017_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0018_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0019_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0020_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0021_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0022_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0023_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0024_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0025_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0026_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0027_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0028_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0029_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0030_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0031_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0032_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0033_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0034_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0035_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0036_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0037_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0038_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0039_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0040_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0041_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0042_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0043_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0044_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0045_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0046_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0047_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0048_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0049_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0050_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0051_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0052_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0053_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0054_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0055_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0056_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0057_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0058_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0059_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0060_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0061_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0062_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0063_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0064_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0065_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0066_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0067_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0068_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0069_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0070_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0071_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0072_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0073_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0074_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0075_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0076_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0077_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0078_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0079_alpha_1.png',
#  'D:/python_project/image_processing/STO_ZA_110/CS_result_jitter_95_85_snap_shot/input_001_0080_alpha_1.png')

# %%
img_adr = img_adr[1::2]
print(len(img_adr))
# Out:
# 81

# %%
import skimage.exposure as exposure

images = []
for adr in img_adr:
    temp = plt.imread(adr)[50:-50, 50:-50, 0]
    temp = temp / np.max(temp)
    images.append(temp)
images = np.asarray(images)
print(images.shape)
# Out:
# (81, 100, 100)

# %%
xsize = 9
ysize = 9
crop_size = 100
ny = xsize * crop_size
nx = ysize * crop_size
    
reconstructed = np.zeros((ny, nx))

k = 0
for i in range(ysize):
    for j in range(xsize):
        reconstructed[i*crop_size:(i+1)*crop_size, j*crop_size:(j+1)*crop_size] = images[k]
        k += 1
        
plt.figure(figsize=(20, 20))
plt.imshow(reconstructed, cmap="afmhot")
plt.show()

# %%
signal_avg = []
for img in images:
    signal_avg.append(np.percentile(img, 50))
signal_avg = np.array(signal_avg)
plt.plot(signal_avg)

# %%
signal_avg_normal = signal_avg / np.max(signal_avg)
adjusted_images = []
for i, img in enumerate(images):
    adjusted_images.append(exposure.adjust_gamma(img, np.exp(0.6*signal_avg_normal[i])))

adjusted_images = np.asarray(adjusted_images)
print(adjusted_images.shape)
    
plt.imshow(adjusted_images[0], cmap="gray")
# Out:
# (81, 100, 100)

# %%
reconstructed_adjusted = np.zeros((ny, nx))

k = 0
for i in range(ysize):
    for j in range(xsize):
        img = plt.imread(img_adr[k])[:, :, 0]
        img = img/np.max(img)
        reconstructed_adjusted[i*crop_size:(i+1)*crop_size, j*crop_size:(j+1)*crop_size] = adjusted_images[k]
        k += 1
        
plt.figure(figsize=(20, 20))
plt.imshow(reconstructed_adjusted, cmap="afmhot")
plt.show()

# %%
save_name = tkf.asksaveasfilename()
plt.imsave(fname=save_name, arr=reconstructed, format="png", cmap="gray")

# %%
save_name = tkf.asksaveasfilename()
plt.imsave(fname=save_name, arr=reconstructed_adjusted, format="png", cmap="gray")
